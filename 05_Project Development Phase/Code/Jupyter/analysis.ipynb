# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("credit_card.csv")

df.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804            1             1                1             0
# 1  5008804            1             1                1             0
# 2  5008804            1             1                1             0
# 3  5008804            1             1                1             0
# 4  5008804            1             1                1             0
#
#    AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0          427500.0                 4                    1
# 1          427500.0                 4                    1
# 2          427500.0                 4                    1
# 3          427500.0                 4                    1
# 4          427500.0                 4                    1
#
#    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                   0                  4  ...           0               18
# 1                   0                  4  ...           0               18
# 2                   0                  4  ...           0               18
# 3                   0                  4  ...           0               18
# 4                   0                  4  ...           0               18
#
#    CNT_FAM_MEMBERS  MONTHS_BALANCE  STATUS  Age  Employment_Years  \
# 0              2.0               0       6   32                12
# 1              2.0              -1       6   32                12
# 2              2.0              -2       6   32                12
# 3              2.0              -3       6   32                12
# 4              2.0              -4       6   32                12
#
#    Income_Per_Person  Income_Group  Age_Group
# 0           213750.0             2          1
# 1           213750.0             2          1
# 2           213750.0             2          1
# 3           213750.0             2          1
# 4           213750.0             2          1
#
# [5 rows x 25 columns]

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 777715
# Columns : 25

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 777715 entries, 0 to 777714
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   777715 non-null  int64
#  1   CODE_GENDER          777715 non-null  int64
#  2   FLAG_OWN_CAR         777715 non-null  int64
#  3   FLAG_OWN_REALTY      777715 non-null  int64
#  4   CNT_CHILDREN         777715 non-null  int64
#  5   AMT_INCOME_TOTAL     777715 non-null  float64
#  6   NAME_INCOME_TYPE     777715 non-null  int64
#  7   NAME_EDUCATION_TYPE  777715 non-null  int64
#  8   NAME_FAMILY_STATUS   777715 non-null  int64
#  9   NAME_HOUSING_TYPE    777715 non-null  int64
#  10  DAYS_BIRTH           777715 non-null  int64
#  11  DAYS_EMPLOYED        777715 non-null  int64
#  12  FLAG_MOBIL           777715 non-null  int64
#  13  FLAG_WORK_PHONE      777715 non-null  int64
#  14  FLAG_PHONE           777715 non-null  int64
#  15  FLAG_EMAIL           777715 non-null  int64
#  16  OCCUPATION_TYPE      777715 non-null  int64
#  17  CNT_FAM_MEMBERS      777715 non-null  float64
#  18  MONTHS_BALANCE       777715 non-null  int64
#  19  STATUS               777715 non-null  int64
#  20  Age                  777715 non-null  int64
#  21  Employment_Years     777715 non-null  int64
#  22  Income_Per_Person    777715 non-null  float64
#  23  Income_Group         777715 non-null  int64
#  24  Age_Group            777715 non-null  int64
# dtypes: float64(3), int64(22)
# memory usage: 148.3 MB

# %%
df.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# MONTHS_BALANCE         0
# STATUS                 0
# Age                    0
# Employment_Years       0
# Income_Per_Person      0
# Income_Group           0
# Age_Group              0
# dtype: int64

# %%
print("Duplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %%
df.describe()
# Out:
#                  ID    CODE_GENDER   FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# count  7.777150e+05  777715.000000  777715.000000    777715.000000
# mean   5.078743e+06       0.332852       0.391352         0.659558
# std    4.180442e+04       0.471234       0.488053         0.473858
# min    5.008804e+06       0.000000       0.000000         0.000000
# 25%    5.044568e+06       0.000000       0.000000         0.000000
# 50%    5.069530e+06       0.000000       0.000000         1.000000
# 75%    5.115551e+06       1.000000       1.000000         1.000000
# max    5.150487e+06       1.000000       1.000000         1.000000
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# count  777715.000000      7.777150e+05     777715.000000        777715.000000
# mean        0.428082      1.885348e+05          2.392821             3.082492
# std         0.745755      1.016225e+05          1.735675             1.347130
# min         0.000000      2.700000e+04          0.000000             0.000000
# 25%         0.000000      1.215000e+05          1.000000             1.000000
# 50%         0.000000      1.620000e+05          4.000000             4.000000
# 75%         1.000000      2.250000e+05          4.000000             4.000000
# max        19.000000      1.575000e+06          4.000000             4.000000
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...     FLAG_EMAIL  \
# count       777715.000000      777715.000000  ...  777715.000000
# mean             1.343410           1.267310  ...       0.091675
# std              0.929344           0.924776  ...       0.288567
# min              0.000000           0.000000  ...       0.000000
# 25%              1.000000           1.000000  ...       0.000000
# 50%              1.000000           1.000000  ...       0.000000
# 75%              1.000000           1.000000  ...       0.000000
# max              4.000000           5.000000  ...       1.000000
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE         STATUS  \
# count    777715.000000    777715.000000   777715.000000  777715.000000
# mean         10.822342         2.208837      -19.373564       3.881324
# std           5.975508         0.907380       14.082208       3.075245
# min           0.000000         1.000000      -60.000000       0.000000
# 25%           6.000000         2.000000      -29.000000       0.000000
# 50%          10.000000         2.000000      -17.000000       6.000000
# 75%          18.000000         3.000000       -8.000000       6.000000
# max          18.000000        20.000000        0.000000       7.000000
#
#                  Age  Employment_Years  Income_Per_Person   Income_Group  \
# count  777715.000000     777715.000000      777715.000000  777715.000000
# mean       43.671326          5.951588      100457.385160       1.024760
# std        11.247138          6.616192       71997.316366       0.167881
# min        20.000000          0.000000        5625.000000       0.000000
# 25%        34.000000          1.000000       56250.000000       1.000000
# 50%        43.000000          4.000000       78750.000000       1.000000
# 75%        53.000000          9.000000      123750.000000       1.000000
# max        68.000000         43.000000      900000.000000       3.000000
#
#            Age_Group
# count  777715.000000
# mean        1.810267
# std         1.176227
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         4.000000
#
# [8 rows x 25 columns]

# %%
df.describe(include='all')
# Out:
#                  ID    CODE_GENDER   FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# count  7.777150e+05  777715.000000  777715.000000    777715.000000
# mean   5.078743e+06       0.332852       0.391352         0.659558
# std    4.180442e+04       0.471234       0.488053         0.473858
# min    5.008804e+06       0.000000       0.000000         0.000000
# 25%    5.044568e+06       0.000000       0.000000         0.000000
# 50%    5.069530e+06       0.000000       0.000000         1.000000
# 75%    5.115551e+06       1.000000       1.000000         1.000000
# max    5.150487e+06       1.000000       1.000000         1.000000
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# count  777715.000000      7.777150e+05     777715.000000        777715.000000
# mean        0.428082      1.885348e+05          2.392821             3.082492
# std         0.745755      1.016225e+05          1.735675             1.347130
# min         0.000000      2.700000e+04          0.000000             0.000000
# 25%         0.000000      1.215000e+05          1.000000             1.000000
# 50%         0.000000      1.620000e+05          4.000000             4.000000
# 75%         1.000000      2.250000e+05          4.000000             4.000000
# max        19.000000      1.575000e+06          4.000000             4.000000
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...     FLAG_EMAIL  \
# count       777715.000000      777715.000000  ...  777715.000000
# mean             1.343410           1.267310  ...       0.091675
# std              0.929344           0.924776  ...       0.288567
# min              0.000000           0.000000  ...       0.000000
# 25%              1.000000           1.000000  ...       0.000000
# 50%              1.000000           1.000000  ...       0.000000
# 75%              1.000000           1.000000  ...       0.000000
# max              4.000000           5.000000  ...       1.000000
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE         STATUS  \
# count    777715.000000    777715.000000   777715.000000  777715.000000
# mean         10.822342         2.208837      -19.373564       3.881324
# std           5.975508         0.907380       14.082208       3.075245
# min           0.000000         1.000000      -60.000000       0.000000
# 25%           6.000000         2.000000      -29.000000       0.000000
# 50%          10.000000         2.000000      -17.000000       6.000000
# 75%          18.000000         3.000000       -8.000000       6.000000
# max          18.000000        20.000000        0.000000       7.000000
#
#                  Age  Employment_Years  Income_Per_Person   Income_Group  \
# count  777715.000000     777715.000000      777715.000000  777715.000000
# mean       43.671326          5.951588      100457.385160       1.024760
# std        11.247138          6.616192       71997.316366       0.167881
# min        20.000000          0.000000        5625.000000       0.000000
# 25%        34.000000          1.000000       56250.000000       1.000000
# 50%        43.000000          4.000000       78750.000000       1.000000
# 75%        53.000000          9.000000      123750.000000       1.000000
# max        68.000000         43.000000      900000.000000       3.000000
#
#            Age_Group
# count  777715.000000
# mean        1.810267
# std         1.176227
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         4.000000
#
# [8 rows x 25 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                            ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# ID                   1.000000     0.010124     -0.010233        -0.096581
# CODE_GENDER          0.010124     1.000000      0.368554        -0.055791
# FLAG_OWN_CAR        -0.010233     0.368554      1.000000        -0.017764
# FLAG_OWN_REALTY     -0.096581    -0.055791     -0.017764         1.000000
# CNT_CHILDREN         0.026269     0.103816      0.109014        -0.010621
# AMT_INCOME_TOTAL    -0.027597     0.203889      0.219579         0.039443
# NAME_INCOME_TYPE     0.023361     0.104403      0.051135        -0.047037
# NAME_EDUCATION_TYPE -0.001140     0.004436     -0.102231         0.011832
# NAME_FAMILY_STATUS  -0.010946    -0.110477     -0.122454         0.026957
# NAME_HOUSING_TYPE    0.016600     0.062915      0.014884        -0.177366
# DAYS_BIRTH           0.042020     0.203718      0.162202        -0.130354
# DAYS_EMPLOYED       -0.025322    -0.172962     -0.157830         0.092166
# FLAG_MOBIL                NaN          NaN           NaN              NaN
# FLAG_WORK_PHONE      0.084800     0.059027      0.019654        -0.210804
# FLAG_PHONE           0.006346    -0.029471     -0.014249        -0.061221
# FLAG_EMAIL          -0.056083    -0.011710      0.029040         0.054065
# OCCUPATION_TYPE     -0.007243    -0.125086     -0.116527         0.050959
# CNT_FAM_MEMBERS      0.027375     0.138505      0.156436        -0.014404
# MONTHS_BALANCE       0.005007     0.013635     -0.003142        -0.008977
# STATUS               0.014255     0.005773      0.000631        -0.002500
# Age                 -0.041938    -0.203546     -0.161807         0.129788
# Employment_Years    -0.006719    -0.040822      0.005192        -0.028427
# Income_Per_Person   -0.034281     0.055487      0.058860         0.046123
# Income_Group        -0.008703     0.045340      0.063246         0.018516
# Age_Group           -0.043719    -0.194140     -0.160099         0.125400
#
#                      CNT_CHILDREN  AMT_INCOME_TOTAL  NAME_INCOME_TYPE  \
# ID                       0.026269         -0.027597          0.023361
# CODE_GENDER              0.103816          0.203889          0.104403
# FLAG_OWN_CAR             0.109014          0.219579          0.051135
# FLAG_OWN_REALTY         -0.010621          0.039443         -0.047037
# CNT_CHILDREN             1.000000          0.039304          0.113271
# AMT_INCOME_TOTAL         0.039304          1.000000         -0.067151
# NAME_INCOME_TYPE         0.113271         -0.067151          1.000000
# NAME_EDUCATION_TYPE     -0.050802         -0.230667          0.068635
# NAME_FAMILY_STATUS      -0.152997         -0.003554         -0.051965
# NAME_HOUSING_TYPE        0.034803         -0.003235          0.037424
# DAYS_BIRTH               0.356177          0.081231          0.199369
# DAYS_EMPLOYED           -0.228945         -0.180674         -0.356812
# FLAG_MOBIL                    NaN               NaN               NaN
# FLAG_WORK_PHONE          0.042226         -0.021229          0.152181
# FLAG_PHONE              -0.018882          0.018687          0.006498
# FLAG_EMAIL               0.015726          0.085776         -0.013586
# OCCUPATION_TYPE         -0.136906         -0.097895         -0.204552
# CNT_FAM_MEMBERS          0.892079          0.031379          0.114460
# MONTHS_BALANCE           0.000913          0.001831         -0.001852
# STATUS                  -0.002850         -0.013499          0.004904
# Age                     -0.356017         -0.081093         -0.199683
# Employment_Years         0.029631          0.081566          0.184120
# Income_Per_Person       -0.334915          0.721043         -0.099572
# Income_Group             0.017776          0.483378         -0.056546
# Age_Group               -0.343143         -0.077884         -0.190398
#
#                      NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# ID                             -0.001140           -0.010946
# CODE_GENDER                     0.004436           -0.110477
# FLAG_OWN_CAR                   -0.102231           -0.122454
# FLAG_OWN_REALTY                 0.011832            0.026957
# CNT_CHILDREN                   -0.050802           -0.152997
# AMT_INCOME_TOTAL               -0.230667           -0.003554
# NAME_INCOME_TYPE                0.068635           -0.051965
# NAME_EDUCATION_TYPE             1.000000            0.001060
# NAME_FAMILY_STATUS              0.001060            1.000000
# NAME_HOUSING_TYPE              -0.022558            0.006143
# DAYS_BIRTH                     -0.169821           -0.119080
# DAYS_EMPLOYED                   0.115720            0.129181
# FLAG_MOBIL                           NaN                 NaN
# FLAG_WORK_PHONE                -0.021927           -0.062684
# FLAG_PHONE                     -0.044448           -0.012902
# FLAG_EMAIL                     -0.094085           -0.003031
# OCCUPATION_TYPE                 0.070259            0.060607
# CNT_FAM_MEMBERS                -0.039851           -0.533478
# MONTHS_BALANCE                 -0.000855            0.012558
# STATUS                         -0.019092           -0.008906
# Age                             0.170176            0.118830
# Employment_Years               -0.008027           -0.043438
# Income_Per_Person              -0.155082            0.462332
# Income_Group                   -0.112672            0.004420
# Age_Group                       0.169411            0.111834
#
#                      NAME_HOUSING_TYPE  ...  FLAG_EMAIL  OCCUPATION_TYPE  \
# ID                            0.016600  ...   -0.056083        -0.007243
# CODE_GENDER                   0.062915  ...   -0.011710        -0.125086
# FLAG_OWN_CAR                  0.014884  ...    0.029040        -0.116527
# FLAG_OWN_REALTY              -0.177366  ...    0.054065         0.050959
# CNT_CHILDREN                  0.034803  ...    0.015726        -0.136906
# AMT_INCOME_TOTAL             -0.003235  ...    0.085776        -0.097895
# NAME_INCOME_TYPE              0.037424  ...   -0.013586        -0.204552
# NAME_EDUCATION_TYPE          -0.022558  ...   -0.094085         0.070259
# NAME_FAMILY_STATUS            0.006143  ...   -0.003031         0.060607
# NAME_HOUSING_TYPE             1.000000  ...    0.006166        -0.070003
# DAYS_BIRTH                    0.196485  ...    0.100945        -0.320134
# DAYS_EMPLOYED                -0.100765  ...   -0.082474         0.533118
# FLAG_MOBIL                         NaN  ...         NaN              NaN
# FLAG_WORK_PHONE               0.029783  ...   -0.037991        -0.153451
# FLAG_PHONE                   -0.010828  ...    0.011901        -0.007680
# FLAG_EMAIL                    0.006166  ...    1.000000        -0.045291
# OCCUPATION_TYPE              -0.070003  ...   -0.045291         1.000000
# CNT_FAM_MEMBERS               0.015255  ...    0.012540        -0.130215
# MONTHS_BALANCE                0.016312  ...    0.005288        -0.001879
# STATUS                       -0.001388  ...   -0.012077        -0.004788
# Age                          -0.195694  ...   -0.100706         0.319896
# Employment_Years             -0.019392  ...   -0.007685        -0.218925
# Income_Per_Person             0.000969  ...    0.062289        -0.030858
# Income_Group                 -0.002678  ...    0.050316        -0.005227
# Age_Group                    -0.185972  ...   -0.094865         0.309900
#
#                      CNT_FAM_MEMBERS  MONTHS_BALANCE    STATUS       Age  \
# ID                          0.027375        0.005007  0.014255 -0.041938
# CODE_GENDER                 0.138505        0.013635  0.005773 -0.203546
# FLAG_OWN_CAR                0.156436       -0.003142  0.000631 -0.161807
# FLAG_OWN_REALTY            -0.014404       -0.008977 -0.002500  0.129788
# CNT_CHILDREN                0.892079        0.000913 -0.002850 -0.356017
# AMT_INCOME_TOTAL            0.031379        0.001831 -0.013499 -0.081093
# NAME_INCOME_TYPE            0.114460       -0.001852  0.004904 -0.199683
# NAME_EDUCATION_TYPE        -0.039851       -0.000855 -0.019092  0.170176
# NAME_FAMILY_STATUS         -0.533478        0.012558 -0.008906  0.118830
# NAME_HOUSING_TYPE           0.015255        0.016312 -0.001388 -0.195694
# DAYS_BIRTH                  0.327750        0.035756  0.005070 -0.999674
# DAYS_EMPLOYED              -0.227645       -0.004222  0.002361  0.608849
# FLAG_MOBIL                       NaN             NaN       NaN       NaN
# FLAG_WORK_PHONE             0.060183        0.001529  0.010512 -0.181275
# FLAG_PHONE                 -0.007824       -0.005120 -0.000747  0.026586
# FLAG_EMAIL                  0.012540        0.005288 -0.012077 -0.100706
# OCCUPATION_TYPE            -0.130215       -0.001879 -0.004788  0.319896
# CNT_FAM_MEMBERS             1.000000       -0.006276 -0.000330 -0.327615
# MONTHS_BALANCE             -0.006276        1.000000  0.140139 -0.035813
# STATUS                     -0.000330        0.140139  1.000000 -0.004859
# Age                        -0.327615       -0.035813 -0.004859  1.000000
# Employment_Years            0.040160       -0.032695  0.001725 -0.014619
# Income_Per_Person          -0.510636        0.008551 -0.014412  0.075107
# Income_Group                0.012143        0.002554 -0.016233  0.008474
# Age_Group                  -0.314799       -0.034248 -0.002869  0.969286
#
#                      Employment_Years  Income_Per_Person  Income_Group  \
# ID                          -0.006719          -0.034281     -0.008703
# CODE_GENDER                 -0.040822           0.055487      0.045340
# FLAG_OWN_CAR                 0.005192           0.058860      0.063246
# FLAG_OWN_REALTY             -0.028427           0.046123      0.018516
# CNT_CHILDREN                 0.029631          -0.334915      0.017776
# AMT_INCOME_TOTAL             0.081566           0.721043      0.483378
# NAME_INCOME_TYPE             0.184120          -0.099572     -0.056546
# NAME_EDUCATION_TYPE         -0.008027          -0.155082     -0.112672
# NAME_FAMILY_STATUS          -0.043438           0.462332      0.004420
# NAME_HOUSING_TYPE           -0.019392           0.000969     -0.002678
# DAYS_BIRTH                   0.013846          -0.074987     -0.009091
# DAYS_EMPLOYED               -0.414007          -0.035223     -0.041900
# FLAG_MOBIL                        NaN                NaN           NaN
# FLAG_WORK_PHONE              0.093934          -0.036928      0.006046
# FLAG_PHONE                   0.034116           0.019127      0.054012
# FLAG_EMAIL                  -0.007685           0.062289      0.050316
# OCCUPATION_TYPE             -0.218925          -0.030858     -0.005227
# CNT_FAM_MEMBERS              0.040160          -0.510636      0.012143
# MONTHS_BALANCE              -0.032695           0.008551      0.002554
# STATUS                       0.001725          -0.014412     -0.016233
# Age                         -0.014619           0.075107      0.008474
# Employment_Years             1.000000           0.038700      0.015963
# Income_Per_Person            0.038700           1.000000      0.368754
# Income_Group                 0.015963           0.368754      1.000000
# Age_Group                   -0.012366           0.071664      0.009797
#
#                      Age_Group
# ID                   -0.043719
# CODE_GENDER          -0.194140
# FLAG_OWN_CAR         -0.160099
# FLAG_OWN_REALTY       0.125400
# CNT_CHILDREN         -0.343143
# AMT_INCOME_TOTAL     -0.077884
# NAME_INCOME_TYPE     -0.190398
# NAME_EDUCATION_TYPE   0.169411
# NAME_FAMILY_STATUS    0.111834
# NAME_HOUSING_TYPE    -0.185972
# DAYS_BIRTH           -0.968857
# DAYS_EMPLOYED         0.585320
# FLAG_MOBIL                 NaN
# FLAG_WORK_PHONE      -0.177191
# FLAG_PHONE            0.026919
# FLAG_EMAIL           -0.094865
# OCCUPATION_TYPE       0.309900
# CNT_FAM_MEMBERS      -0.314799
# MONTHS_BALANCE       -0.034248
# STATUS               -0.002869
# Age                   0.969286
# Employment_Years     -0.012366
# Income_Per_Person     0.071664
# Income_Group          0.009797
# Age_Group             1.000000
#
# [25 rows x 25 columns]

# %%
df.hist(figsize=(15,10))

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=30, kde=True)

plt.title("Age Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x=df["AMT_INCOME_TOTAL"])

plt.title("Income Boxplot")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="CODE_GENDER", data=df)

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(6,6))

df["CODE_GENDER"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.show()

# %%
df.to_csv("credit_card_cleaned.csv", index=False)

print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully
